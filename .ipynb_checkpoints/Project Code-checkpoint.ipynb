# %%
import pandas as pd
import numpy as np


df = pd.read_csv('data/unclean_data.csv')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#    Unnamed: 0    G        Date       Opp W/L     Tm  Opp.1    FG   FGA    FG%  \
# 0           0  1.0  2009-10-28  NaN  IND   W  120.0  109.0  46.0  87.0  0.529
# 1           1  2.0  2009-10-30  NaN  WAS   W  100.0   89.0  32.0  78.0  0.410
# 2           2  3.0  2009-11-01    @  LAL   L  110.0  118.0  40.0  89.0  0.449
# 3           3  4.0  2009-11-03    @  POR   W   97.0   91.0  37.0  80.0  0.463
# 4           4  5.0  2009-11-04    @  SAC   W  113.0  105.0  46.0  85.0  0.541
#
#     3P   3PA    3P%    FT   FTA    FT%   ORB   TRB   AST   STL   BLK   TOV  \
# 0  7.0  12.0  0.583  21.0  29.0  0.724   8.0  35.0  30.0  16.0   6.0  10.0
# 1  5.0  20.0  0.250  31.0  34.0  0.912  11.0  47.0  18.0   5.0   7.0  12.0
# 2  7.0  23.0  0.304  23.0  26.0  0.885  14.0  40.0  21.0   8.0   3.0  19.0
# 3  5.0  15.0  0.333  18.0  22.0  0.818  11.0  46.0  21.0   4.0   7.0  11.0
# 4  6.0  16.0  0.375  15.0  19.0  0.789  12.0  47.0  17.0   2.0  10.0  16.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26458 entries, 0 to 26457
# Data columns (total 44 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26458 non-null  int64
#  1   G           24118 non-null  float64
#  2   Date        24118 non-null  object
#  3               12059 non-null  object
#  4   Opp         24118 non-null  object
#  5   W/L         24118 non-null  object
#  6   Tm          24118 non-null  float64
#  7   Opp.1       24118 non-null  float64
#  8   FG          24118 non-null  float64
#  9   FGA         24118 non-null  float64
#  10  FG%         24118 non-null  float64
#  11  3P          24118 non-null  float64
#  12  3PA         24118 non-null  float64
#  13  3P%         24118 non-null  float64
#  14  FT          24118 non-null  float64
#  15  FTA         24118 non-null  float64
#  16  FT%         24118 non-null  float64
#  17  ORB         24118 non-null  float64
# ...

# %%
#Change column name to Home/away
df.rename(columns={'\xa0':'Home/Away'}, inplace=True)

# %%
df.drop(df.columns[[34, 39]], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26458 entries, 0 to 26457
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26458 non-null  int64
#  1   G           24118 non-null  float64
#  2   Date        24118 non-null  object
#  3   Home/Away   12059 non-null  object
#  4   Opp         24118 non-null  object
#  5   W/L         24118 non-null  object
#  6   Tm          24118 non-null  float64
#  7   Opp.1       24118 non-null  float64
#  8   FG          24118 non-null  float64
#  9   FGA         24118 non-null  float64
#  10  FG%         24118 non-null  float64
#  11  3P          24118 non-null  float64
#  12  3PA         24118 non-null  float64
#  13  3P%         24118 non-null  float64
#  14  FT          24118 non-null  float64
#  15  FTA         24118 non-null  float64
#  16  FT%         24118 non-null  float64
#  17  ORB         24118 non-null  float64
# ...

# %%
# Drop the .1 and .2 columns

# rename the columns for O and D 4 factors
